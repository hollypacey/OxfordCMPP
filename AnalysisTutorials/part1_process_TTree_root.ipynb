# %%
import ROOT as r
from ROOT import TH1D, TFile, TChain, TCanvas, TBranchElement, TLorentzVector

import sys
sys.path.insert(0, '../utils/')

from utils import createDirs

import os
from array import array

luminosity_ifb = 10.

# Define out input and output paths, make sure the output path exists.
ntuple_path = "../data/GamGam/"
output_path = "../histograms/GamGam_root/"
createDirs(output_path)

# %%
def getNEvents(tree):
    """
    # TODO
    """
    nentries = tree.GetEntries()
    if (nentries==0):
        print("oh no, the files are empty or read in wrong :( ")
        sys.exit()
    return nentries

# %%
def setupHist1D(file, name, nbins, xlow, xhigh, xlab):
    """
    # TODO
    """
    hist = TH1D(name, name+";"+xlab+";Events / bin", nbins, xlow, xhigh)
    # Make sure it stores sum of weights squared and sets bin errors as sqrt(sum-of-weights), correct for weighted histogram.
    hist.Sumw2()
    hist.SetDirectory(file)
    print("Registering histogram... ",name)
    return hist

# %%
def initialiseSingleBranch(tree, branchname, vartype="f"):
    """
    Function to initialise a TBranch in the input TTree which has 1 entry per event (e.g. event number, cross section, event weight)

    Args:
        tree (ROOT TTree): input TTree that has the TBranch
        branchname (str): name of the TBranch
        vartype (str): type of branch (f, i, b python array types supported)
    Returns:
        vartype branch variable
    """
    if vartype not in ["i", "f", "b"]:
        raise Exception("not set up to read a TBranch of type {}, need to improve function beyond f/i/b...".format(vartype))
    tree.SetBranchStatus(branchname,1)
    variable = array(vartype,[0])
    tree.SetBranchAddress( branchname, variable)
    return variable

def initialiseVectorBranch(tree, branchname, vartype="float"):
    """
    Function to initialise a TBranch in the input TTree which has multiple entries per event (e.g. a property for all the particles of a given type that were made)

    Args:
        tree (ROOT TTree): input TTree that has the TBranch
        branchname (str): name of the TBranch
        vartype (str): type of branch (float, int, bool root types supported)
    Returns:
        ROOT.Vector branch variable
    """
    if vartype not in ["int", "float", "bool"]:
        raise Exception("not set up to read a TBranch of type {}, need to improve function beyond float/int/bool...".format(vartype))
    tree.SetBranchStatus(branchname,1)
    variable = r.std.vector(vartype)()
    tree.SetBranchAddress( branchname, r.AddressOf(variable))
    return variable

# %%
# now loop over each event, retrieve the needed info from the ntuple, check if the event passes our selection, and fill histograms for the output.
def eventLooper (tree, out_hists, is_data):
    """
    # TODO
    """

    nentries = getNEvents(tree)
    print("there are {} event in the TTree".format(nentries))

    photon_pt = initialiseVectorBranch(tree, "photon_pt", "float")
    photon_E = initialiseVectorBranch(tree, "photon_E", "float")
    photon_eta = initialiseVectorBranch(tree, "photon_eta", "float")
    photon_phi = initialiseVectorBranch(tree, "photon_phi", "float")

    mc_weight = initialiseSingleBranch(tree, "mcWeight", "f")
    xsec_ipb = initialiseSingleBranch(tree, "XSection", "f")
    sum_weights = initialiseSingleBranch(tree, "SumWeights", "f")

    SF_pileup = initialiseSingleBranch(tree, "scaleFactor_PILEUP", "f")
    # TODO include the scaleFactor_PHOTON in the event weight

    hist_pTGam_1 = setupHist1D(out_hists, "photon_pT_1", 100, 0., 500., "pT [GeV]")
    hist_pTGam_2 = setupHist1D(out_hists, "photon_pT_2", 100, 0., 500., "pT [GeV]")
    hist_EGam_1 = setupHist1D(out_hists, "photon_E_1", 100, 0., 500., "E [GeV]")
    hist_EGam_2 = setupHist1D(out_hists, "photon_E_2", 100, 0., 500., "E [GeV]")
    hist_etaGam_1 = setupHist1D(out_hists, "photon_eta_1", 10, -2.5, 2.5, "#eta")
    hist_etaGam_2 = setupHist1D(out_hists, "photon_eta_2", 10, -2.5, 2.5, "#eta")
    hist_phiGam_1 = setupHist1D(out_hists, "photon_phi_1", 10, -4., 4., "#phi")
    hist_phiGam_2 = setupHist1D(out_hists, "photon_phi_2", 10, -4., 4., "#phi")
    hist_mGamGam = setupHist1D(out_hists, "diphoton_mass", 100, 0., 1000., "m#gamma#gamma [GeV]")

    for entry in range(1, nentries):
#         # some printout to track progress
        if (entry%5000 == 0):
            pcnt_done = 100.*float(entry)/float(nentries)
            print("Processed {0} events, {1:.0f}% done.".format(entry, pcnt_done))

#         # read the entry from the ntuple
        tree.GetEntry(entry)

        # read in the event weight
        if (is_data):
            histoweight = 1.0
        else:
            # MC event weighting to luminosity of data
            histoweight = mc_weight[0] * xsec_ipb[0]*1000. * luminosity_ifb / sum_weights[0]
            # MC weight corrections for experimental effects
            histoweight = histoweight * SF_pileup[0] # TODO multiply by the photon scale factor weight

        # Need events that have at least 2 photons in to start with.
        if not (len(photon_pt) >= 2): continue
        
        # Obtain the kinematic variables (note TTree is in MeV and I want GeV)
        photon_1_pt = photon_pt[0]*0.001
        photon_2_pt = photon_pt[1]*0.001
        photon_1_E = photon_E[0]*0.001
        photon_2_E = photon_E[1]*0.001
        photon_1_eta = photon_eta[0]
        photon_2_eta = photon_eta[1]
        photon_1_phi = photon_phi[0]
        photon_2_phi = photon_phi[1]

        # Need to check the photons are in the fiducial region
        if not ((abs(photon_1_eta) < 2.37 and (abs(photon_1_eta) < 1.37 or abs(photon_1_eta) > 1.56)) and\
                (abs(photon_2_eta) < 2.37 and (abs(photon_2_eta) < 1.37 or abs(photon_2_eta) > 1.56))): continue

        # We need to apply the photon trigger requirements, approximated by requiring our photons to have photon 1(2) pT > 35(25) GeV
        if not (photon_1_pt > 35. and photon_2_pt > 25.): continue


        # TODO we're also only interested in the case where our two photons have passed a Tight particle ID, to reduce misreconstruction backgrounds.
        # Can you use the boolean "photon_isTightID" vector branch to require this?..

        # Only interested in events that have exactly 2 photons in that pass those requirements.
        if not (len(photon_pt) == 2): continue

        photon_1_p4 = TLorentzVector()
        photon_1_p4.SetPtEtaPhiE(photon_1_pt, photon_1_eta, photon_1_phi, photon_1_E)
        photon_2_p4 = TLorentzVector()
        photon_2_p4.SetPtEtaPhiE(photon_2_pt, photon_2_eta, photon_2_phi, photon_2_E)

        diphoton_mass = (photon_1_p4 + photon_2_p4).M()

        # Another requirement for the events is a pT/diphoton mass bound
        if not (photon_1_pt/diphoton_mass > 0.35 and photon_2_pt/diphoton_mass > 0.25): continue

        # Fill the histograms in the output file with the event values.
        hist_pTGam_1.Fill(photon_1_pt, histoweight)
        hist_pTGam_2.Fill(photon_2_pt, histoweight)
        hist_EGam_1.Fill(photon_1_E, histoweight)
        hist_EGam_2.Fill(photon_2_E, histoweight)
        hist_etaGam_1.Fill(photon_1_eta, histoweight)
        hist_etaGam_2.Fill(photon_2_eta, histoweight)
        hist_phiGam_1.Fill(photon_1_phi, histoweight)
        hist_phiGam_2.Fill(photon_2_phi, histoweight)
        hist_mGamGam.Fill(diphoton_mass, histoweight)

    # write histograms to root file for further analysis.
    out_hists.Write()
    out_hists.Close()

# %%
# EventLoop analysis over the Data 

# write the file we will output our data histograms into
out_hists_data = TFile.Open(output_path+"data.root", "RECREATE")

# read in our data ntuples
tree_data = TChain("mini")
datafiles = [ntuple_path+"/Data/data_"+i+".GamGam.root" for i in ["A", "B", "C", "D"]]
for filename in datafiles:
    tree_data.Add(filename)

# loop over the data ntuple to process needed info into histograms
eventLooper(tree_data, out_hists_data, True)
# Out:
# there are 7798424 event in the TTree
# Registering histogram...  photon_pT_1
# Registering histogram...  photon_pT_2
# Registering histogram...  photon_E_1
# Registering histogram...  photon_E_2
# Registering histogram...  photon_eta_1
# Registering histogram...  photon_eta_2
# Registering histogram...  photon_phi_1
# Registering histogram...  photon_phi_2
# Registering histogram...  diphoton_mass
# Processed 5000 events, 0% done.
# Processed 10000 events, 0% done.
# Processed 15000 events, 0% done.
# Processed 20000 events, 0% done.
# Processed 25000 events, 0% done.
# Processed 30000 events, 0% done.
# Processed 35000 events, 0% done.
# Processed 40000 events, 1% done.
# Processed 45000 events, 1% done.
# Processed 50000 events, 1% done.
# Processed 55000 events, 1% done.
# Processed 60000 events, 1% done.
# Processed 65000 events, 1% done.
# Processed 70000 events, 1% done.
# Processed 75000 events, 1% done.
# Processed 80000 events, 1% done.
# Processed 85000 events, 1% done.
# Processed 90000 events, 1% done.
# Processed 95000 events, 1% done.
# Processed 100000 events, 1% done.
# Processed 105000 events, 1% done.
# Processed 110000 events, 1% done.
# Processed 115000 events, 1% done.
# Processed 120000 events, 2% done.
# Processed 125000 events, 2% done.
# Processed 130000 events, 2% done.
# Processed 135000 events, 2% done.
# Processed 140000 events, 2% done.
# Processed 145000 events, 2% done.
# Processed 150000 events, 2% done.
# Processed 155000 events, 2% done.
# Processed 160000 events, 2% done.
# Processed 165000 events, 2% done.
# Processed 170000 events, 2% done.
# Processed 175000 events, 2% done.
# Processed 180000 events, 2% done.
# Processed 185000 events, 2% done.
# Processed 190000 events, 2% done.
# Processed 195000 events, 3% done.
# Processed 200000 events, 3% done.
# Processed 205000 events, 3% done.
# Processed 210000 events, 3% done.
# Processed 215000 events, 3% done.
# Processed 220000 events, 3% done.
# Processed 225000 events, 3% done.
# Processed 230000 events, 3% done.
# Processed 235000 events, 3% done.
# Processed 240000 events, 3% done.
# Processed 245000 events, 3% done.
# Processed 250000 events, 3% done.
# Processed 255000 events, 3% done.
# Processed 260000 events, 3% done.
# Processed 265000 events, 3% done.
# Processed 270000 events, 3% done.
# Processed 275000 events, 4% done.
# Processed 280000 events, 4% done.
# Processed 285000 events, 4% done.
# Processed 290000 events, 4% done.
# Processed 295000 events, 4% done.
# Processed 300000 events, 4% done.
# Processed 305000 events, 4% done.
# Processed 310000 events, 4% done.
# Processed 315000 events, 4% done.
# Processed 320000 events, 4% done.
# Processed 325000 events, 4% done.
# Processed 330000 events, 4% done.
# Processed 335000 events, 4% done.
# Processed 340000 events, 4% done.
# Processed 345000 events, 4% done.
# Processed 350000 events, 4% done.
# Processed 355000 events, 5% done.
# Processed 360000 events, 5% done.
# Processed 365000 events, 5% done.
# Processed 370000 events, 5% done.
# Processed 375000 events, 5% done.
# Processed 380000 events, 5% done.
# Processed 385000 events, 5% done.
# Processed 390000 events, 5% done.
# Processed 395000 events, 5% done.
# Processed 400000 events, 5% done.
# Processed 405000 events, 5% done.
# Processed 410000 events, 5% done.
# Processed 415000 events, 5% done.
# Processed 420000 events, 5% done.
# Processed 425000 events, 5% done.
# Processed 430000 events, 6% done.
# Processed 435000 events, 6% done.
# Processed 440000 events, 6% done.
# Processed 445000 events, 6% done.
# Processed 450000 events, 6% done.
# Processed 455000 events, 6% done.
# Processed 460000 events, 6% done.
# Processed 465000 events, 6% done.
# Processed 470000 events, 6% done.
# Processed 475000 events, 6% done.
# Processed 480000 events, 6% done.
# Processed 485000 events, 6% done.
# Processed 490000 events, 6% done.
# Processed 495000 events, 6% done.
# Processed 500000 events, 6% done.
# Processed 505000 events, 6% done.
# Processed 510000 events, 7% done.
# Processed 515000 events, 7% done.
# Processed 520000 events, 7% done.
# Processed 525000 events, 7% done.
# Processed 530000 events, 7% done.
# Processed 535000 events, 7% done.
# Processed 540000 events, 7% done.
# Processed 545000 events, 7% done.
# Processed 550000 events, 7% done.
# Processed 555000 events, 7% done.
# Processed 560000 events, 7% done.
# Processed 565000 events, 7% done.
# Processed 570000 events, 7% done.
# Processed 575000 events, 7% done.
# Processed 580000 events, 7% done.
# Processed 585000 events, 8% done.
# Processed 590000 events, 8% done.
# Processed 595000 events, 8% done.
# Processed 600000 events, 8% done.
# Processed 605000 events, 8% done.
# Processed 610000 events, 8% done.
# Processed 615000 events, 8% done.
# Processed 620000 events, 8% done.
# Processed 625000 events, 8% done.
# Processed 630000 events, 8% done.
# Processed 635000 events, 8% done.
# Processed 640000 events, 8% done.
# Processed 645000 events, 8% done.
# Processed 650000 events, 8% done.
# Processed 655000 events, 8% done.
# Processed 660000 events, 8% done.
# Processed 665000 events, 9% done.
# Processed 670000 events, 9% done.
# Processed 675000 events, 9% done.
# Processed 680000 events, 9% done.
# Processed 685000 events, 9% done.
# Processed 690000 events, 9% done.
# Processed 695000 events, 9% done.
# Processed 700000 events, 9% done.
# Processed 705000 events, 9% done.
# Processed 710000 events, 9% done.
# Processed 715000 events, 9% done.
# Processed 720000 events, 9% done.
# Processed 725000 events, 9% done.
# Processed 730000 events, 9% done.
# Processed 735000 events, 9% done.
# Processed 740000 events, 9% done.
# Processed 745000 events, 10% done.
# Processed 750000 events, 10% done.
# Processed 755000 events, 10% done.
# Processed 760000 events, 10% done.
# Processed 765000 events, 10% done.
# Processed 770000 events, 10% done.
# Processed 775000 events, 10% done.
# Processed 780000 events, 10% done.
# Processed 785000 events, 10% done.
# Processed 790000 events, 10% done.
# Processed 795000 events, 10% done.
# Processed 800000 events, 10% done.
# Processed 805000 events, 10% done.
# Processed 810000 events, 10% done.
# Processed 815000 events, 10% done.
# Processed 820000 events, 11% done.
# Processed 825000 events, 11% done.
# Processed 830000 events, 11% done.
# Processed 835000 events, 11% done.
# Processed 840000 events, 11% done.
# Processed 845000 events, 11% done.
# Processed 850000 events, 11% done.
# Processed 855000 events, 11% done.
# Processed 860000 events, 11% done.
# Processed 865000 events, 11% done.
# Processed 870000 events, 11% done.
# Processed 875000 events, 11% done.
# Processed 880000 events, 11% done.
# Processed 885000 events, 11% done.
# Processed 890000 events, 11% done.
# Processed 895000 events, 11% done.
# Processed 900000 events, 12% done.
# Processed 905000 events, 12% done.
# Processed 910000 events, 12% done.
# Processed 915000 events, 12% done.
# Processed 920000 events, 12% done.
# Processed 925000 events, 12% done.
# Processed 930000 events, 12% done.
# Processed 935000 events, 12% done.
# Processed 940000 events, 12% done.
# Processed 945000 events, 12% done.
# Processed 950000 events, 12% done.
# Processed 955000 events, 12% done.
# Processed 960000 events, 12% done.
# Processed 965000 events, 12% done.
# Processed 970000 events, 12% done.
# Processed 975000 events, 13% done.
# Processed 980000 events, 13% done.
# Processed 985000 events, 13% done.
# Processed 990000 events, 13% done.
# Processed 995000 events, 13% done.
# Processed 1000000 events, 13% done.
# Processed 1005000 events, 13% done.
# Processed 1010000 events, 13% done.
# Processed 1015000 events, 13% done.
# Processed 1020000 events, 13% done.
# Processed 1025000 events, 13% done.
# Processed 1030000 events, 13% done.
# Processed 1035000 events, 13% done.
# Processed 1040000 events, 13% done.
# Processed 1045000 events, 13% done.
# Processed 1050000 events, 13% done.
# Processed 1055000 events, 14% done.
# Processed 1060000 events, 14% done.
# Processed 1065000 events, 14% done.
# Processed 1070000 events, 14% done.
# Processed 1075000 events, 14% done.
# Processed 1080000 events, 14% done.
# Processed 1085000 events, 14% done.
# Processed 1090000 events, 14% done.
# Processed 1095000 events, 14% done.
# Processed 1100000 events, 14% done.
# Processed 1105000 events, 14% done.
# Processed 1110000 events, 14% done.
# Processed 1115000 events, 14% done.
# Processed 1120000 events, 14% done.
# Processed 1125000 events, 14% done.
# Processed 1130000 events, 14% done.
# Processed 1135000 events, 15% done.
# Processed 1140000 events, 15% done.
# Processed 1145000 events, 15% done.
# Processed 1150000 events, 15% done.
# Processed 1155000 events, 15% done.
# Processed 1160000 events, 15% done.
# Processed 1165000 events, 15% done.
# Processed 1170000 events, 15% done.
# Processed 1175000 events, 15% done.
# Processed 1180000 events, 15% done.
# Processed 1185000 events, 15% done.
# Processed 1190000 events, 15% done.
# Processed 1195000 events, 15% done.
# Processed 1200000 events, 15% done.
# Processed 1205000 events, 15% done.
# Processed 1210000 events, 16% done.
# Processed 1215000 events, 16% done.
# Processed 1220000 events, 16% done.
# Processed 1225000 events, 16% done.
# Processed 1230000 events, 16% done.
# Processed 1235000 events, 16% done.
# Processed 1240000 events, 16% done.
# Processed 1245000 events, 16% done.
# Processed 1250000 events, 16% done.
# Processed 1255000 events, 16% done.
# Processed 1260000 events, 16% done.
# Processed 1265000 events, 16% done.
# Processed 1270000 events, 16% done.
# Processed 1275000 events, 16% done.
# Processed 1280000 events, 16% done.
# Processed 1285000 events, 16% done.
# Processed 1290000 events, 17% done.
# Processed 1295000 events, 17% done.
# Processed 1300000 events, 17% done.
# Processed 1305000 events, 17% done.
# Processed 1310000 events, 17% done.
# Processed 1315000 events, 17% done.
# Processed 1320000 events, 17% done.
# Processed 1325000 events, 17% done.
# Processed 1330000 events, 17% done.
# Processed 1335000 events, 17% done.
# Processed 1340000 events, 17% done.
# Processed 1345000 events, 17% done.
# Processed 1350000 events, 17% done.
# Processed 1355000 events, 17% done.
# Processed 1360000 events, 17% done.
# Processed 1365000 events, 18% done.
# Processed 1370000 events, 18% done.
# Processed 1375000 events, 18% done.
# Processed 1380000 events, 18% done.
# Processed 1385000 events, 18% done.
# Processed 1390000 events, 18% done.
# Processed 1395000 events, 18% done.
# Processed 1400000 events, 18% done.
# Processed 1405000 events, 18% done.
# Processed 1410000 events, 18% done.
# Processed 1415000 events, 18% done.
# Processed 1420000 events, 18% done.
# Processed 1425000 events, 18% done.
# Processed 1430000 events, 18% done.
# Processed 1435000 events, 18% done.
# Processed 1440000 events, 18% done.
# Processed 1445000 events, 19% done.
# Processed 1450000 events, 19% done.
# Processed 1455000 events, 19% done.
# Processed 1460000 events, 19% done.
# Processed 1465000 events, 19% done.
# Processed 1470000 events, 19% done.
# Processed 1475000 events, 19% done.
# Processed 1480000 events, 19% done.
# Processed 1485000 events, 19% done.
# Processed 1490000 events, 19% done.
# Processed 1495000 events, 19% done.
# Processed 1500000 events, 19% done.
# Processed 1505000 events, 19% done.
# Processed 1510000 events, 19% done.
# Processed 1515000 events, 19% done.
# Processed 1520000 events, 19% done.
# Processed 1525000 events, 20% done.
# Processed 1530000 events, 20% done.
# Processed 1535000 events, 20% done.
# Processed 1540000 events, 20% done.
# Processed 1545000 events, 20% done.
# Processed 1550000 events, 20% done.
# Processed 1555000 events, 20% done.
# Processed 1560000 events, 20% done.
# Processed 1565000 events, 20% done.
# Processed 1570000 events, 20% done.
# Processed 1575000 events, 20% done.
# Processed 1580000 events, 20% done.
# Processed 1585000 events, 20% done.
# Processed 1590000 events, 20% done.
# Processed 1595000 events, 20% done.
# Processed 1600000 events, 21% done.
# Processed 1605000 events, 21% done.
# Processed 1610000 events, 21% done.
# Processed 1615000 events, 21% done.
# Processed 1620000 events, 21% done.
# Processed 1625000 events, 21% done.
# Processed 1630000 events, 21% done.
# Processed 1635000 events, 21% done.
# Processed 1640000 events, 21% done.
# Processed 1645000 events, 21% done.
# Processed 1650000 events, 21% done.
# Processed 1655000 events, 21% done.
# Processed 1660000 events, 21% done.
# Processed 1665000 events, 21% done.
# Processed 1670000 events, 21% done.
# Processed 1675000 events, 21% done.
# Processed 1680000 events, 22% done.
# Processed 1685000 events, 22% done.
# Processed 1690000 events, 22% done.
# Processed 1695000 events, 22% done.
# Processed 1700000 events, 22% done.
# Processed 1705000 events, 22% done.
# Processed 1710000 events, 22% done.
# Processed 1715000 events, 22% done.
# Processed 1720000 events, 22% done.
# Processed 1725000 events, 22% done.
# Processed 1730000 events, 22% done.
# Processed 1735000 events, 22% done.
# Processed 1740000 events, 22% done.
# Processed 1745000 events, 22% done.
# Processed 1750000 events, 22% done.
# Processed 1755000 events, 23% done.
# Processed 1760000 events, 23% done.
# Processed 1765000 events, 23% done.
# Processed 1770000 events, 23% done.
# Processed 1775000 events, 23% done.
# Processed 1780000 events, 23% done.
# Processed 1785000 events, 23% done.
# Processed 1790000 events, 23% done.
# Processed 1795000 events, 23% done.
# Processed 1800000 events, 23% done.
# Processed 1805000 events, 23% done.
# Processed 1810000 events, 23% done.
# Processed 1815000 events, 23% done.
# Processed 1820000 events, 23% done.
# Processed 1825000 events, 23% done.
# Processed 1830000 events, 23% done.
# Processed 1835000 events, 24% done.
# Processed 1840000 events, 24% done.
# Processed 1845000 events, 24% done.
# Processed 1850000 events, 24% done.
# Processed 1855000 events, 24% done.
# Processed 1860000 events, 24% done.
# Processed 1865000 events, 24% done.
# Processed 1870000 events, 24% done.
# Processed 1875000 events, 24% done.
# Processed 1880000 events, 24% done.
# Processed 1885000 events, 24% done.
# Processed 1890000 events, 24% done.
# Processed 1895000 events, 24% done.
# Processed 1900000 events, 24% done.
# Processed 1905000 events, 24% done.
# Processed 1910000 events, 24% done.
# Processed 1915000 events, 25% done.
# Processed 1920000 events, 25% done.
# Processed 1925000 events, 25% done.
# Processed 1930000 events, 25% done.
# Processed 1935000 events, 25% done.
# Processed 1940000 events, 25% done.
# Processed 1945000 events, 25% done.
# Processed 1950000 events, 25% done.
# Processed 1955000 events, 25% done.
# Processed 1960000 events, 25% done.
# Processed 1965000 events, 25% done.
# Processed 1970000 events, 25% done.
# Processed 1975000 events, 25% done.
# Processed 1980000 events, 25% done.
# Processed 1985000 events, 25% done.
# Processed 1990000 events, 26% done.
# Processed 1995000 events, 26% done.
# Processed 2000000 events, 26% done.
# Processed 2005000 events, 26% done.
# Processed 2010000 events, 26% done.
# Processed 2015000 events, 26% done.
# Processed 2020000 events, 26% done.
# Processed 2025000 events, 26% done.
# Processed 2030000 events, 26% done.
# Processed 2035000 events, 26% done.
# Processed 2040000 events, 26% done.
# Processed 2045000 events, 26% done.
# Processed 2050000 events, 26% done.
# Processed 2055000 events, 26% done.
# Processed 2060000 events, 26% done.
# Processed 2065000 events, 26% done.
# Processed 2070000 events, 27% done.
# Processed 2075000 events, 27% done.
# Processed 2080000 events, 27% done.
# Processed 2085000 events, 27% done.
# Processed 2090000 events, 27% done.
# Processed 2095000 events, 27% done.
# Processed 2100000 events, 27% done.
# Processed 2105000 events, 27% done.
# Processed 2110000 events, 27% done.
# Processed 2115000 events, 27% done.
# Processed 2120000 events, 27% done.
# Processed 2125000 events, 27% done.
# Processed 2130000 events, 27% done.
# Processed 2135000 events, 27% done.
# Processed 2140000 events, 27% done.
# Processed 2145000 events, 28% done.
# Processed 2150000 events, 28% done.
# Processed 2155000 events, 28% done.
# Processed 2160000 events, 28% done.
# Processed 2165000 events, 28% done.
# Processed 2170000 events, 28% done.
# Processed 2175000 events, 28% done.
# Processed 2180000 events, 28% done.
# Processed 2185000 events, 28% done.
# Processed 2190000 events, 28% done.
# Processed 2195000 events, 28% done.
# Processed 2200000 events, 28% done.
# Processed 2205000 events, 28% done.
# Processed 2210000 events, 28% done.
# Processed 2215000 events, 28% done.
# Processed 2220000 events, 28% done.
# Processed 2225000 events, 29% done.
# Processed 2230000 events, 29% done.
# Processed 2235000 events, 29% done.
# Processed 2240000 events, 29% done.
# Processed 2245000 events, 29% done.
# Processed 2250000 events, 29% done.
# Processed 2255000 events, 29% done.
# Processed 2260000 events, 29% done.
# Processed 2265000 events, 29% done.
# Processed 2270000 events, 29% done.
# Processed 2275000 events, 29% done.
# Processed 2280000 events, 29% done.
# Processed 2285000 events, 29% done.
# Processed 2290000 events, 29% done.
# Processed 2295000 events, 29% done.
# Processed 2300000 events, 29% done.
# Processed 2305000 events, 30% done.
# Processed 2310000 events, 30% done.
# Processed 2315000 events, 30% done.
# Processed 2320000 events, 30% done.
# Processed 2325000 events, 30% done.
# Processed 2330000 events, 30% done.
# Processed 2335000 events, 30% done.
# Processed 2340000 events, 30% done.
# Processed 2345000 events, 30% done.
# Processed 2350000 events, 30% done.
# Processed 2355000 events, 30% done.
# Processed 2360000 events, 30% done.
# Processed 2365000 events, 30% done.
# Processed 2370000 events, 30% done.
# Processed 2375000 events, 30% done.
# Processed 2380000 events, 31% done.
# Processed 2385000 events, 31% done.
# Processed 2390000 events, 31% done.
# Processed 2395000 events, 31% done.
# Processed 2400000 events, 31% done.
# Processed 2405000 events, 31% done.
# Processed 2410000 events, 31% done.
# Processed 2415000 events, 31% done.
# Processed 2420000 events, 31% done.
# Processed 2425000 events, 31% done.
# Processed 2430000 events, 31% done.
# Processed 2435000 events, 31% done.
# Processed 2440000 events, 31% done.
# Processed 2445000 events, 31% done.
# Processed 2450000 events, 31% done.
# Processed 2455000 events, 31% done.
# Processed 2460000 events, 32% done.
# Processed 2465000 events, 32% done.
# Processed 2470000 events, 32% done.
# Processed 2475000 events, 32% done.
# Processed 2480000 events, 32% done.
# Processed 2485000 events, 32% done.
# Processed 2490000 events, 32% done.
# Processed 2495000 events, 32% done.
# Processed 2500000 events, 32% done.
# Processed 2505000 events, 32% done.
# Processed 2510000 events, 32% done.
# Processed 2515000 events, 32% done.
# Processed 2520000 events, 32% done.
# Processed 2525000 events, 32% done.
# Processed 2530000 events, 32% done.
# Processed 2535000 events, 33% done.
# Processed 2540000 events, 33% done.
# Processed 2545000 events, 33% done.
# Processed 2550000 events, 33% done.
# Processed 2555000 events, 33% done.
# Processed 2560000 events, 33% done.
# Processed 2565000 events, 33% done.
# Processed 2570000 events, 33% done.
# Processed 2575000 events, 33% done.
# Processed 2580000 events, 33% done.
# Processed 2585000 events, 33% done.
# Processed 2590000 events, 33% done.
# Processed 2595000 events, 33% done.
# Processed 2600000 events, 33% done.
# Processed 2605000 events, 33% done.
# Processed 2610000 events, 33% done.
# Processed 2615000 events, 34% done.
# Processed 2620000 events, 34% done.
# Processed 2625000 events, 34% done.
# Processed 2630000 events, 34% done.
# Processed 2635000 events, 34% done.
# Processed 2640000 events, 34% done.
# Processed 2645000 events, 34% done.
# Processed 2650000 events, 34% done.
# Processed 2655000 events, 34% done.
# Processed 2660000 events, 34% done.
# Processed 2665000 events, 34% done.
# Processed 2670000 events, 34% done.
# Processed 2675000 events, 34% done.
# Processed 2680000 events, 34% done.
# Processed 2685000 events, 34% done.
# Processed 2690000 events, 34% done.
# Processed 2695000 events, 35% done.
# Processed 2700000 events, 35% done.
# Processed 2705000 events, 35% done.
# Processed 2710000 events, 35% done.
# Processed 2715000 events, 35% done.
# Processed 2720000 events, 35% done.
# Processed 2725000 events, 35% done.
# Processed 2730000 events, 35% done.
# Processed 2735000 events, 35% done.
# Processed 2740000 events, 35% done.
# Processed 2745000 events, 35% done.
# Processed 2750000 events, 35% done.
# Processed 2755000 events, 35% done.
# Processed 2760000 events, 35% done.
# Processed 2765000 events, 35% done.
# Processed 2770000 events, 36% done.
# Processed 2775000 events, 36% done.
# Processed 2780000 events, 36% done.
# Processed 2785000 events, 36% done.
# Processed 2790000 events, 36% done.
# Processed 2795000 events, 36% done.
# Processed 2800000 events, 36% done.
# Processed 2805000 events, 36% done.
# Processed 2810000 events, 36% done.
# Processed 2815000 events, 36% done.
# Processed 2820000 events, 36% done.
# Processed 2825000 events, 36% done.
# Processed 2830000 events, 36% done.
# Processed 2835000 events, 36% done.
# Processed 2840000 events, 36% done.
# Processed 2845000 events, 36% done.
# Processed 2850000 events, 37% done.
# Processed 2855000 events, 37% done.
# Processed 2860000 events, 37% done.
# Processed 2865000 events, 37% done.
# Processed 2870000 events, 37% done.
# Processed 2875000 events, 37% done.
# Processed 2880000 events, 37% done.
# Processed 2885000 events, 37% done.
# Processed 2890000 events, 37% done.
# Processed 2895000 events, 37% done.
# Processed 2900000 events, 37% done.
# Processed 2905000 events, 37% done.
# Processed 2910000 events, 37% done.
# Processed 2915000 events, 37% done.
# Processed 2920000 events, 37% done.
# Processed 2925000 events, 38% done.
# Processed 2930000 events, 38% done.
# Processed 2935000 events, 38% done.
# Processed 2940000 events, 38% done.
# Processed 2945000 events, 38% done.
# Processed 2950000 events, 38% done.
# Processed 2955000 events, 38% done.
# Processed 2960000 events, 38% done.
# Processed 2965000 events, 38% done.
# Processed 2970000 events, 38% done.
# Processed 2975000 events, 38% done.
# Processed 2980000 events, 38% done.
# Processed 2985000 events, 38% done.
# Processed 2990000 events, 38% done.
# Processed 2995000 events, 38% done.
# Processed 3000000 events, 38% done.
# Processed 3005000 events, 39% done.
# Processed 3010000 events, 39% done.
# Processed 3015000 events, 39% done.
# Processed 3020000 events, 39% done.
# Processed 3025000 events, 39% done.
# Processed 3030000 events, 39% done.
# Processed 3035000 events, 39% done.
# Processed 3040000 events, 39% done.
# Processed 3045000 events, 39% done.
# Processed 3050000 events, 39% done.
# Processed 3055000 events, 39% done.
# Processed 3060000 events, 39% done.
# Processed 3065000 events, 39% done.
# Processed 3070000 events, 39% done.
# Processed 3075000 events, 39% done.
# Processed 3080000 events, 39% done.
# Processed 3085000 events, 40% done.
# Processed 3090000 events, 40% done.
# Processed 3095000 events, 40% done.
# Processed 3100000 events, 40% done.
# Processed 3105000 events, 40% done.
# Processed 3110000 events, 40% done.
# Processed 3115000 events, 40% done.
# Processed 3120000 events, 40% done.
# Processed 3125000 events, 40% done.
# Processed 3130000 events, 40% done.
# Processed 3135000 events, 40% done.
# Processed 3140000 events, 40% done.
# Processed 3145000 events, 40% done.
# Processed 3150000 events, 40% done.
# Processed 3155000 events, 40% done.
# Processed 3160000 events, 41% done.
# Processed 3165000 events, 41% done.
# Processed 3170000 events, 41% done.
# Processed 3175000 events, 41% done.
# Processed 3180000 events, 41% done.
# Processed 3185000 events, 41% done.
# Processed 3190000 events, 41% done.
# Processed 3195000 events, 41% done.
# Processed 3200000 events, 41% done.
# Processed 3205000 events, 41% done.
# Processed 3210000 events, 41% done.
# Processed 3215000 events, 41% done.
# Processed 3220000 events, 41% done.
# Processed 3225000 events, 41% done.
# Processed 3230000 events, 41% done.
# Processed 3235000 events, 41% done.
# Processed 3240000 events, 42% done.
# Processed 3245000 events, 42% done.
# Processed 3250000 events, 42% done.
# Processed 3255000 events, 42% done.
# Processed 3260000 events, 42% done.
# Processed 3265000 events, 42% done.
# Processed 3270000 events, 42% done.
# Processed 3275000 events, 42% done.
# Processed 3280000 events, 42% done.
# Processed 3285000 events, 42% done.
# Processed 3290000 events, 42% done.
# Processed 3295000 events, 42% done.
# Processed 3300000 events, 42% done.
# Processed 3305000 events, 42% done.
# Processed 3310000 events, 42% done.
# Processed 3315000 events, 43% done.
# Processed 3320000 events, 43% done.
# Processed 3325000 events, 43% done.
# Processed 3330000 events, 43% done.
# Processed 3335000 events, 43% done.
# Processed 3340000 events, 43% done.
# Processed 3345000 events, 43% done.
# Processed 3350000 events, 43% done.
# Processed 3355000 events, 43% done.
# Processed 3360000 events, 43% done.
# Processed 3365000 events, 43% done.
# Processed 3370000 events, 43% done.
# Processed 3375000 events, 43% done.
# Processed 3380000 events, 43% done.
# Processed 3385000 events, 43% done.
# Processed 3390000 events, 43% done.
# Processed 3395000 events, 44% done.
# Processed 3400000 events, 44% done.
# Processed 3405000 events, 44% done.
# Processed 3410000 events, 44% done.
# Processed 3415000 events, 44% done.
# Processed 3420000 events, 44% done.
# Processed 3425000 events, 44% done.
# Processed 3430000 events, 44% done.
# Processed 3435000 events, 44% done.
# Processed 3440000 events, 44% done.
# Processed 3445000 events, 44% done.
# Processed 3450000 events, 44% done.
# Processed 3455000 events, 44% done.
# Processed 3460000 events, 44% done.
# Processed 3465000 events, 44% done.
# Processed 3470000 events, 44% done.
# Processed 3475000 events, 45% done.
# Processed 3480000 events, 45% done.
# Processed 3485000 events, 45% done.
# Processed 3490000 events, 45% done.
# Processed 3495000 events, 45% done.
# Processed 3500000 events, 45% done.
# Processed 3505000 events, 45% done.
# Processed 3510000 events, 45% done.
# Processed 3515000 events, 45% done.
# Processed 3520000 events, 45% done.
# Processed 3525000 events, 45% done.
# Processed 3530000 events, 45% done.
# Processed 3535000 events, 45% done.
# Processed 3540000 events, 45% done.
# Processed 3545000 events, 45% done.
# Processed 3550000 events, 46% done.
# Processed 3555000 events, 46% done.
# Processed 3560000 events, 46% done.
# Processed 3565000 events, 46% done.
# Processed 3570000 events, 46% done.
# Processed 3575000 events, 46% done.
# Processed 3580000 events, 46% done.
# Processed 3585000 events, 46% done.
# Processed 3590000 events, 46% done.
# Processed 3595000 events, 46% done.
# Processed 3600000 events, 46% done.
# Processed 3605000 events, 46% done.
# Processed 3610000 events, 46% done.
# Processed 3615000 events, 46% done.
# Processed 3620000 events, 46% done.
# Processed 3625000 events, 46% done.
# Processed 3630000 events, 47% done.
# Processed 3635000 events, 47% done.
# Processed 3640000 events, 47% done.
# Processed 3645000 events, 47% done.
# Processed 3650000 events, 47% done.
# Processed 3655000 events, 47% done.
# Processed 3660000 events, 47% done.
# Processed 3665000 events, 47% done.
# Processed 3670000 events, 47% done.
# Processed 3675000 events, 47% done.
# Processed 3680000 events, 47% done.
# Processed 3685000 events, 47% done.
# Processed 3690000 events, 47% done.
# Processed 3695000 events, 47% done.
# Processed 3700000 events, 47% done.
# Processed 3705000 events, 48% done.
# Processed 3710000 events, 48% done.
# Processed 3715000 events, 48% done.
# Processed 3720000 events, 48% done.
# Processed 3725000 events, 48% done.
# Processed 3730000 events, 48% done.
# Processed 3735000 events, 48% done.
# Processed 3740000 events, 48% done.
# Processed 3745000 events, 48% done.
# Processed 3750000 events, 48% done.
# Processed 3755000 events, 48% done.
# Processed 3760000 events, 48% done.
# Processed 3765000 events, 48% done.
# Processed 3770000 events, 48% done.
# Processed 3775000 events, 48% done.
# Processed 3780000 events, 48% done.
# Processed 3785000 events, 49% done.
# Processed 3790000 events, 49% done.
# Processed 3795000 events, 49% done.
# Processed 3800000 events, 49% done.
# Processed 3805000 events, 49% done.
# Processed 3810000 events, 49% done.
# Processed 3815000 events, 49% done.
# Processed 3820000 events, 49% done.
# Processed 3825000 events, 49% done.
# Processed 3830000 events, 49% done.
# Processed 3835000 events, 49% done.
# Processed 3840000 events, 49% done.
# Processed 3845000 events, 49% done.
# Processed 3850000 events, 49% done.
# Processed 3855000 events, 49% done.
# Processed 3860000 events, 49% done.
# Processed 3865000 events, 50% done.
# Processed 3870000 events, 50% done.
# Processed 3875000 events, 50% done.
# Processed 3880000 events, 50% done.
# Processed 3885000 events, 50% done.
# Processed 3890000 events, 50% done.
# Processed 3895000 events, 50% done.
# Processed 3900000 events, 50% done.
# Processed 3905000 events, 50% done.
# Processed 3910000 events, 50% done.
# Processed 3915000 events, 50% done.
# Processed 3920000 events, 50% done.
# Processed 3925000 events, 50% done.
# Processed 3930000 events, 50% done.
# Processed 3935000 events, 50% done.
# Processed 3940000 events, 51% done.
# Processed 3945000 events, 51% done.
# Processed 3950000 events, 51% done.
# Processed 3955000 events, 51% done.
# Processed 3960000 events, 51% done.
# Processed 3965000 events, 51% done.
# Processed 3970000 events, 51% done.
# Processed 3975000 events, 51% done.
# Processed 3980000 events, 51% done.
# Processed 3985000 events, 51% done.
# Processed 3990000 events, 51% done.
# Processed 3995000 events, 51% done.
# Processed 4000000 events, 51% done.
# Processed 4005000 events, 51% done.
# Processed 4010000 events, 51% done.
# Processed 4015000 events, 51% done.
# Processed 4020000 events, 52% done.
# Processed 4025000 events, 52% done.
# Processed 4030000 events, 52% done.
# Processed 4035000 events, 52% done.
# Processed 4040000 events, 52% done.
# Processed 4045000 events, 52% done.
# Processed 4050000 events, 52% done.
# Processed 4055000 events, 52% done.
# Processed 4060000 events, 52% done.
# Processed 4065000 events, 52% done.
# Processed 4070000 events, 52% done.
# Processed 4075000 events, 52% done.
# Processed 4080000 events, 52% done.
# Processed 4085000 events, 52% done.
# Processed 4090000 events, 52% done.
# Processed 4095000 events, 53% done.
# Processed 4100000 events, 53% done.
# Processed 4105000 events, 53% done.
# Processed 4110000 events, 53% done.
# Processed 4115000 events, 53% done.
# Processed 4120000 events, 53% done.
# Processed 4125000 events, 53% done.
# Processed 4130000 events, 53% done.
# Processed 4135000 events, 53% done.
# Processed 4140000 events, 53% done.
# Processed 4145000 events, 53% done.
# Processed 4150000 events, 53% done.
# Processed 4155000 events, 53% done.
# Processed 4160000 events, 53% done.
# Processed 4165000 events, 53% done.
# Processed 4170000 events, 53% done.
# Processed 4175000 events, 54% done.
# Processed 4180000 events, 54% done.
# Processed 4185000 events, 54% done.
# Processed 4190000 events, 54% done.
# Processed 4195000 events, 54% done.
# Processed 4200000 events, 54% done.
# Processed 4205000 events, 54% done.
# Processed 4210000 events, 54% done.
# Processed 4215000 events, 54% done.
# Processed 4220000 events, 54% done.
# Processed 4225000 events, 54% done.
# Processed 4230000 events, 54% done.
# Processed 4235000 events, 54% done.
# Processed 4240000 events, 54% done.
# Processed 4245000 events, 54% done.
# Processed 4250000 events, 54% done.
# Processed 4255000 events, 55% done.
# Processed 4260000 events, 55% done.
# Processed 4265000 events, 55% done.
# Processed 4270000 events, 55% done.
# Processed 4275000 events, 55% done.
# Processed 4280000 events, 55% done.
# Processed 4285000 events, 55% done.
# Processed 4290000 events, 55% done.
# Processed 4295000 events, 55% done.
# Processed 4300000 events, 55% done.
# Processed 4305000 events, 55% done.
# Processed 4310000 events, 55% done.
# Processed 4315000 events, 55% done.
# Processed 4320000 events, 55% done.
# Processed 4325000 events, 55% done.
# Processed 4330000 events, 56% done.
# Processed 4335000 events, 56% done.
# Processed 4340000 events, 56% done.
# Processed 4345000 events, 56% done.
# Processed 4350000 events, 56% done.
# Processed 4355000 events, 56% done.
# Processed 4360000 events, 56% done.
# Processed 4365000 events, 56% done.
# Processed 4370000 events, 56% done.
# Processed 4375000 events, 56% done.
# Processed 4380000 events, 56% done.
# Processed 4385000 events, 56% done.
# Processed 4390000 events, 56% done.
# Processed 4395000 events, 56% done.
# Processed 4400000 events, 56% done.
# Processed 4405000 events, 56% done.
# Processed 4410000 events, 57% done.
# Processed 4415000 events, 57% done.
# Processed 4420000 events, 57% done.
# Processed 4425000 events, 57% done.
# Processed 4430000 events, 57% done.
# Processed 4435000 events, 57% done.
# Processed 4440000 events, 57% done.
# Processed 4445000 events, 57% done.
# Processed 4450000 events, 57% done.
# Processed 4455000 events, 57% done.
# Processed 4460000 events, 57% done.
# Processed 4465000 events, 57% done.
# Processed 4470000 events, 57% done.
# Processed 4475000 events, 57% done.
# Processed 4480000 events, 57% done.
# Processed 4485000 events, 58% done.
# Processed 4490000 events, 58% done.
# Processed 4495000 events, 58% done.
# Processed 4500000 events, 58% done.
# Processed 4505000 events, 58% done.
# Processed 4510000 events, 58% done.
# Processed 4515000 events, 58% done.
# Processed 4520000 events, 58% done.
# Processed 4525000 events, 58% done.
# Processed 4530000 events, 58% done.
# Processed 4535000 events, 58% done.
# Processed 4540000 events, 58% done.
# Processed 4545000 events, 58% done.
# Processed 4550000 events, 58% done.
# Processed 4555000 events, 58% done.
# Processed 4560000 events, 58% done.
# Processed 4565000 events, 59% done.
# Processed 4570000 events, 59% done.
# Processed 4575000 events, 59% done.
# Processed 4580000 events, 59% done.
# Processed 4585000 events, 59% done.
# Processed 4590000 events, 59% done.
# Processed 4595000 events, 59% done.
# Processed 4600000 events, 59% done.
# Processed 4605000 events, 59% done.
# Processed 4610000 events, 59% done.
# Processed 4615000 events, 59% done.
# Processed 4620000 events, 59% done.
# Processed 4625000 events, 59% done.
# Processed 4630000 events, 59% done.
# Processed 4635000 events, 59% done.
# Processed 4640000 events, 59% done.
# Processed 4645000 events, 60% done.
# Processed 4650000 events, 60% done.
# Processed 4655000 events, 60% done.
# Processed 4660000 events, 60% done.
# Processed 4665000 events, 60% done.
# Processed 4670000 events, 60% done.
# Processed 4675000 events, 60% done.
# Processed 4680000 events, 60% done.
# Processed 4685000 events, 60% done.
# Processed 4690000 events, 60% done.
# Processed 4695000 events, 60% done.
# Processed 4700000 events, 60% done.
# Processed 4705000 events, 60% done.
# Processed 4710000 events, 60% done.
# Processed 4715000 events, 60% done.
# Processed 4720000 events, 61% done.
# Processed 4725000 events, 61% done.
# Processed 4730000 events, 61% done.
# Processed 4735000 events, 61% done.
# Processed 4740000 events, 61% done.
# Processed 4745000 events, 61% done.
# Processed 4750000 events, 61% done.
# Processed 4755000 events, 61% done.
# Processed 4760000 events, 61% done.
# Processed 4765000 events, 61% done.
# Processed 4770000 events, 61% done.
# Processed 4775000 events, 61% done.
# Processed 4780000 events, 61% done.
# Processed 4785000 events, 61% done.
# Processed 4790000 events, 61% done.
# Processed 4795000 events, 61% done.
# Processed 4800000 events, 62% done.
# Processed 4805000 events, 62% done.
# Processed 4810000 events, 62% done.
# Processed 4815000 events, 62% done.
# Processed 4820000 events, 62% done.
# Processed 4825000 events, 62% done.
# Processed 4830000 events, 62% done.
# Processed 4835000 events, 62% done.
# Processed 4840000 events, 62% done.
# Processed 4845000 events, 62% done.
# Processed 4850000 events, 62% done.
# Processed 4855000 events, 62% done.
# Processed 4860000 events, 62% done.
# Processed 4865000 events, 62% done.
# Processed 4870000 events, 62% done.
# Processed 4875000 events, 63% done.
# Processed 4880000 events, 63% done.
# Processed 4885000 events, 63% done.
# Processed 4890000 events, 63% done.
# Processed 4895000 events, 63% done.
# Processed 4900000 events, 63% done.
# Processed 4905000 events, 63% done.
# Processed 4910000 events, 63% done.
# Processed 4915000 events, 63% done.
# Processed 4920000 events, 63% done.
# Processed 4925000 events, 63% done.
# Processed 4930000 events, 63% done.
# Processed 4935000 events, 63% done.
# Processed 4940000 events, 63% done.
# Processed 4945000 events, 63% done.
# Processed 4950000 events, 63% done.
# Processed 4955000 events, 64% done.
# Processed 4960000 events, 64% done.
# Processed 4965000 events, 64% done.
# Processed 4970000 events, 64% done.
# Processed 4975000 events, 64% done.
# Processed 4980000 events, 64% done.
# Processed 4985000 events, 64% done.
# Processed 4990000 events, 64% done.
# Processed 4995000 events, 64% done.
# Processed 5000000 events, 64% done.
# Processed 5005000 events, 64% done.
# Processed 5010000 events, 64% done.
# Processed 5015000 events, 64% done.
# Processed 5020000 events, 64% done.
# Processed 5025000 events, 64% done.
# Processed 5030000 events, 65% done.
# Processed 5035000 events, 65% done.
# Processed 5040000 events, 65% done.
# Processed 5045000 events, 65% done.
# Processed 5050000 events, 65% done.
# Processed 5055000 events, 65% done.
# Processed 5060000 events, 65% done.
# Processed 5065000 events, 65% done.
# Processed 5070000 events, 65% done.
# Processed 5075000 events, 65% done.
# Processed 5080000 events, 65% done.
# Processed 5085000 events, 65% done.
# Processed 5090000 events, 65% done.
# Processed 5095000 events, 65% done.
# Processed 5100000 events, 65% done.
# Processed 5105000 events, 65% done.
# Processed 5110000 events, 66% done.
# Processed 5115000 events, 66% done.
# Processed 5120000 events, 66% done.
# Processed 5125000 events, 66% done.
# Processed 5130000 events, 66% done.
# Processed 5135000 events, 66% done.
# Processed 5140000 events, 66% done.
# Processed 5145000 events, 66% done.
# Processed 5150000 events, 66% done.
# Processed 5155000 events, 66% done.
# Processed 5160000 events, 66% done.
# Processed 5165000 events, 66% done.
# Processed 5170000 events, 66% done.
# Processed 5175000 events, 66% done.
# Processed 5180000 events, 66% done.
# Processed 5185000 events, 66% done.
# Processed 5190000 events, 67% done.
# Processed 5195000 events, 67% done.
# Processed 5200000 events, 67% done.
# Processed 5205000 events, 67% done.
# Processed 5210000 events, 67% done.
# Processed 5215000 events, 67% done.
# Processed 5220000 events, 67% done.
# Processed 5225000 events, 67% done.
# Processed 5230000 events, 67% done.
# Processed 5235000 events, 67% done.
# Processed 5240000 events, 67% done.
# Processed 5245000 events, 67% done.
# Processed 5250000 events, 67% done.
# Processed 5255000 events, 67% done.
# Processed 5260000 events, 67% done.
# Processed 5265000 events, 68% done.
# Processed 5270000 events, 68% done.
# Processed 5275000 events, 68% done.
# Processed 5280000 events, 68% done.
# Processed 5285000 events, 68% done.
# Processed 5290000 events, 68% done.
# Processed 5295000 events, 68% done.
# Processed 5300000 events, 68% done.
# Processed 5305000 events, 68% done.
# Processed 5310000 events, 68% done.
# Processed 5315000 events, 68% done.
# Processed 5320000 events, 68% done.
# Processed 5325000 events, 68% done.
# Processed 5330000 events, 68% done.
# Processed 5335000 events, 68% done.
# Processed 5340000 events, 68% done.
# Processed 5345000 events, 69% done.
# Processed 5350000 events, 69% done.
# Processed 5355000 events, 69% done.
# Processed 5360000 events, 69% done.
# Processed 5365000 events, 69% done.
# Processed 5370000 events, 69% done.
# Processed 5375000 events, 69% done.
# Processed 5380000 events, 69% done.
# Processed 5385000 events, 69% done.
# Processed 5390000 events, 69% done.
# Processed 5395000 events, 69% done.
# Processed 5400000 events, 69% done.
# Processed 5405000 events, 69% done.
# Processed 5410000 events, 69% done.
# Processed 5415000 events, 69% done.
# Processed 5420000 events, 70% done.
# Processed 5425000 events, 70% done.
# Processed 5430000 events, 70% done.
# Processed 5435000 events, 70% done.
# Processed 5440000 events, 70% done.
# Processed 5445000 events, 70% done.
# Processed 5450000 events, 70% done.
# Processed 5455000 events, 70% done.
# Processed 5460000 events, 70% done.
# Processed 5465000 events, 70% done.
# Processed 5470000 events, 70% done.
# Processed 5475000 events, 70% done.
# Processed 5480000 events, 70% done.
# Processed 5485000 events, 70% done.
# Processed 5490000 events, 70% done.
# Processed 5495000 events, 70% done.
# Processed 5500000 events, 71% done.
# Processed 5505000 events, 71% done.
# Processed 5510000 events, 71% done.
# Processed 5515000 events, 71% done.
# Processed 5520000 events, 71% done.
# Processed 5525000 events, 71% done.
# Processed 5530000 events, 71% done.
# Processed 5535000 events, 71% done.
# Processed 5540000 events, 71% done.
# Processed 5545000 events, 71% done.
# Processed 5550000 events, 71% done.
# Processed 5555000 events, 71% done.
# Processed 5560000 events, 71% done.
# Processed 5565000 events, 71% done.
# Processed 5570000 events, 71% done.
# Processed 5575000 events, 71% done.
# Processed 5580000 events, 72% done.
# Processed 5585000 events, 72% done.
# Processed 5590000 events, 72% done.
# Processed 5595000 events, 72% done.
# Processed 5600000 events, 72% done.
# Processed 5605000 events, 72% done.
# Processed 5610000 events, 72% done.
# Processed 5615000 events, 72% done.
# Processed 5620000 events, 72% done.
# Processed 5625000 events, 72% done.
# Processed 5630000 events, 72% done.
# Processed 5635000 events, 72% done.
# Processed 5640000 events, 72% done.
# Processed 5645000 events, 72% done.
# Processed 5650000 events, 72% done.
# Processed 5655000 events, 73% done.
# Processed 5660000 events, 73% done.
# Processed 5665000 events, 73% done.
# Processed 5670000 events, 73% done.
# Processed 5675000 events, 73% done.
# Processed 5680000 events, 73% done.
# Processed 5685000 events, 73% done.
# Processed 5690000 events, 73% done.
# Processed 5695000 events, 73% done.
# Processed 5700000 events, 73% done.
# Processed 5705000 events, 73% done.
# Processed 5710000 events, 73% done.
# Processed 5715000 events, 73% done.
# Processed 5720000 events, 73% done.
# Processed 5725000 events, 73% done.
# Processed 5730000 events, 73% done.
# Processed 5735000 events, 74% done.
# Processed 5740000 events, 74% done.
# Processed 5745000 events, 74% done.
# Processed 5750000 events, 74% done.
# Processed 5755000 events, 74% done.
# Processed 5760000 events, 74% done.
# Processed 5765000 events, 74% done.
# Processed 5770000 events, 74% done.
# Processed 5775000 events, 74% done.
# Processed 5780000 events, 74% done.
# Processed 5785000 events, 74% done.
# Processed 5790000 events, 74% done.
# Processed 5795000 events, 74% done.
# Processed 5800000 events, 74% done.
# Processed 5805000 events, 74% done.
# Processed 5810000 events, 75% done.
# Processed 5815000 events, 75% done.
# Processed 5820000 events, 75% done.
# Processed 5825000 events, 75% done.
# Processed 5830000 events, 75% done.
# Processed 5835000 events, 75% done.
# Processed 5840000 events, 75% done.
# Processed 5845000 events, 75% done.
# Processed 5850000 events, 75% done.
# Processed 5855000 events, 75% done.
# Processed 5860000 events, 75% done.
# Processed 5865000 events, 75% done.
# Processed 5870000 events, 75% done.
# Processed 5875000 events, 75% done.
# Processed 5880000 events, 75% done.
# Processed 5885000 events, 75% done.
# Processed 5890000 events, 76% done.
# Processed 5895000 events, 76% done.
# Processed 5900000 events, 76% done.
# Processed 5905000 events, 76% done.
# Processed 5910000 events, 76% done.
# Processed 5915000 events, 76% done.
# Processed 5920000 events, 76% done.
# Processed 5925000 events, 76% done.
# Processed 5930000 events, 76% done.
# Processed 5935000 events, 76% done.
# Processed 5940000 events, 76% done.
# Processed 5945000 events, 76% done.
# Processed 5950000 events, 76% done.
# Processed 5955000 events, 76% done.
# Processed 5960000 events, 76% done.
# Processed 5965000 events, 76% done.
# Processed 5970000 events, 77% done.
# Processed 5975000 events, 77% done.
# Processed 5980000 events, 77% done.
# Processed 5985000 events, 77% done.
# Processed 5990000 events, 77% done.
# Processed 5995000 events, 77% done.
# Processed 6000000 events, 77% done.
# Processed 6005000 events, 77% done.
# Processed 6010000 events, 77% done.
# Processed 6015000 events, 77% done.
# Processed 6020000 events, 77% done.
# Processed 6025000 events, 77% done.
# Processed 6030000 events, 77% done.
# Processed 6035000 events, 77% done.
# Processed 6040000 events, 77% done.
# Processed 6045000 events, 78% done.
# Processed 6050000 events, 78% done.
# Processed 6055000 events, 78% done.
# Processed 6060000 events, 78% done.
# Processed 6065000 events, 78% done.
# Processed 6070000 events, 78% done.
# Processed 6075000 events, 78% done.
# Processed 6080000 events, 78% done.
# Processed 6085000 events, 78% done.
# Processed 6090000 events, 78% done.
# Processed 6095000 events, 78% done.
# Processed 6100000 events, 78% done.
# Processed 6105000 events, 78% done.
# Processed 6110000 events, 78% done.
# Processed 6115000 events, 78% done.
# Processed 6120000 events, 78% done.
# Processed 6125000 events, 79% done.
# Processed 6130000 events, 79% done.
# Processed 6135000 events, 79% done.
# Processed 6140000 events, 79% done.
# Processed 6145000 events, 79% done.
# Processed 6150000 events, 79% done.
# Processed 6155000 events, 79% done.
# Processed 6160000 events, 79% done.
# Processed 6165000 events, 79% done.
# Processed 6170000 events, 79% done.
# Processed 6175000 events, 79% done.
# Processed 6180000 events, 79% done.
# Processed 6185000 events, 79% done.
# Processed 6190000 events, 79% done.
# Processed 6195000 events, 79% done.
# Processed 6200000 events, 80% done.
# Processed 6205000 events, 80% done.
# Processed 6210000 events, 80% done.
# Processed 6215000 events, 80% done.
# Processed 6220000 events, 80% done.
# Processed 6225000 events, 80% done.
# Processed 6230000 events, 80% done.
# Processed 6235000 events, 80% done.
# Processed 6240000 events, 80% done.
# Processed 6245000 events, 80% done.
# Processed 6250000 events, 80% done.
# Processed 6255000 events, 80% done.
# Processed 6260000 events, 80% done.
# Processed 6265000 events, 80% done.
# Processed 6270000 events, 80% done.
# Processed 6275000 events, 80% done.
# Processed 6280000 events, 81% done.
# Processed 6285000 events, 81% done.
# Processed 6290000 events, 81% done.
# Processed 6295000 events, 81% done.
# Processed 6300000 events, 81% done.
# Processed 6305000 events, 81% done.
# Processed 6310000 events, 81% done.
# Processed 6315000 events, 81% done.
# Processed 6320000 events, 81% done.
# Processed 6325000 events, 81% done.
# Processed 6330000 events, 81% done.
# Processed 6335000 events, 81% done.
# Processed 6340000 events, 81% done.
# Processed 6345000 events, 81% done.
# Processed 6350000 events, 81% done.
# Processed 6355000 events, 81% done.
# Processed 6360000 events, 82% done.
# Processed 6365000 events, 82% done.
# Processed 6370000 events, 82% done.
# Processed 6375000 events, 82% done.
# Processed 6380000 events, 82% done.
# Processed 6385000 events, 82% done.
# Processed 6390000 events, 82% done.
# Processed 6395000 events, 82% done.
# Processed 6400000 events, 82% done.
# Processed 6405000 events, 82% done.
# Processed 6410000 events, 82% done.
# Processed 6415000 events, 82% done.
# Processed 6420000 events, 82% done.
# Processed 6425000 events, 82% done.
# Processed 6430000 events, 82% done.
# Processed 6435000 events, 83% done.
# Processed 6440000 events, 83% done.
# Processed 6445000 events, 83% done.
# Processed 6450000 events, 83% done.
# Processed 6455000 events, 83% done.
# Processed 6460000 events, 83% done.
# Processed 6465000 events, 83% done.
# Processed 6470000 events, 83% done.
# Processed 6475000 events, 83% done.
# Processed 6480000 events, 83% done.
# Processed 6485000 events, 83% done.
# Processed 6490000 events, 83% done.
# Processed 6495000 events, 83% done.
# Processed 6500000 events, 83% done.
# Processed 6505000 events, 83% done.
# Processed 6510000 events, 83% done.
# Processed 6515000 events, 84% done.
# Processed 6520000 events, 84% done.
# Processed 6525000 events, 84% done.
# Processed 6530000 events, 84% done.
# Processed 6535000 events, 84% done.
# Processed 6540000 events, 84% done.
# Processed 6545000 events, 84% done.
# Processed 6550000 events, 84% done.
# Processed 6555000 events, 84% done.
# Processed 6560000 events, 84% done.
# Processed 6565000 events, 84% done.
# Processed 6570000 events, 84% done.
# Processed 6575000 events, 84% done.
# Processed 6580000 events, 84% done.
# Processed 6585000 events, 84% done.
# Processed 6590000 events, 85% done.
# Processed 6595000 events, 85% done.
# Processed 6600000 events, 85% done.
# Processed 6605000 events, 85% done.
# Processed 6610000 events, 85% done.
# Processed 6615000 events, 85% done.
# Processed 6620000 events, 85% done.
# Processed 6625000 events, 85% done.
# Processed 6630000 events, 85% done.
# Processed 6635000 events, 85% done.
# Processed 6640000 events, 85% done.
# Processed 6645000 events, 85% done.
# Processed 6650000 events, 85% done.
# Processed 6655000 events, 85% done.
# Processed 6660000 events, 85% done.
# Processed 6665000 events, 85% done.
# Processed 6670000 events, 86% done.
# Processed 6675000 events, 86% done.
# Processed 6680000 events, 86% done.
# Processed 6685000 events, 86% done.
# Processed 6690000 events, 86% done.
# Processed 6695000 events, 86% done.
# Processed 6700000 events, 86% done.
# Processed 6705000 events, 86% done.
# Processed 6710000 events, 86% done.
# Processed 6715000 events, 86% done.
# Processed 6720000 events, 86% done.
# Processed 6725000 events, 86% done.
# Processed 6730000 events, 86% done.
# Processed 6735000 events, 86% done.
# Processed 6740000 events, 86% done.
# Processed 6745000 events, 86% done.
# Processed 6750000 events, 87% done.
# Processed 6755000 events, 87% done.
# Processed 6760000 events, 87% done.
# Processed 6765000 events, 87% done.
# Processed 6770000 events, 87% done.
# Processed 6775000 events, 87% done.
# Processed 6780000 events, 87% done.
# Processed 6785000 events, 87% done.
# Processed 6790000 events, 87% done.
# Processed 6795000 events, 87% done.
# Processed 6800000 events, 87% done.
# Processed 6805000 events, 87% done.
# Processed 6810000 events, 87% done.
# Processed 6815000 events, 87% done.
# Processed 6820000 events, 87% done.
# Processed 6825000 events, 88% done.
# Processed 6830000 events, 88% done.
# Processed 6835000 events, 88% done.
# Processed 6840000 events, 88% done.
# Processed 6845000 events, 88% done.
# Processed 6850000 events, 88% done.
# Processed 6855000 events, 88% done.
# Processed 6860000 events, 88% done.
# Processed 6865000 events, 88% done.
# Processed 6870000 events, 88% done.
# Processed 6875000 events, 88% done.
# Processed 6880000 events, 88% done.
# Processed 6885000 events, 88% done.
# Processed 6890000 events, 88% done.
# Processed 6895000 events, 88% done.
# Processed 6900000 events, 88% done.
# Processed 6905000 events, 89% done.
# Processed 6910000 events, 89% done.
# Processed 6915000 events, 89% done.
# Processed 6920000 events, 89% done.
# Processed 6925000 events, 89% done.
# Processed 6930000 events, 89% done.
# Processed 6935000 events, 89% done.
# Processed 6940000 events, 89% done.
# Processed 6945000 events, 89% done.
# Processed 6950000 events, 89% done.
# Processed 6955000 events, 89% done.
# Processed 6960000 events, 89% done.
# Processed 6965000 events, 89% done.
# Processed 6970000 events, 89% done.
# Processed 6975000 events, 89% done.
# Processed 6980000 events, 90% done.
# Processed 6985000 events, 90% done.
# Processed 6990000 events, 90% done.
# Processed 6995000 events, 90% done.
# Processed 7000000 events, 90% done.
# Processed 7005000 events, 90% done.
# Processed 7010000 events, 90% done.
# Processed 7015000 events, 90% done.
# Processed 7020000 events, 90% done.
# Processed 7025000 events, 90% done.
# Processed 7030000 events, 90% done.
# Processed 7035000 events, 90% done.
# Processed 7040000 events, 90% done.
# Processed 7045000 events, 90% done.
# Processed 7050000 events, 90% done.
# Processed 7055000 events, 90% done.
# Processed 7060000 events, 91% done.
# Processed 7065000 events, 91% done.
# Processed 7070000 events, 91% done.
# Processed 7075000 events, 91% done.
# Processed 7080000 events, 91% done.
# Processed 7085000 events, 91% done.
# Processed 7090000 events, 91% done.
# Processed 7095000 events, 91% done.
# Processed 7100000 events, 91% done.
# Processed 7105000 events, 91% done.
# Processed 7110000 events, 91% done.
# Processed 7115000 events, 91% done.
# Processed 7120000 events, 91% done.
# Processed 7125000 events, 91% done.
# Processed 7130000 events, 91% done.
# Processed 7135000 events, 91% done.
# Processed 7140000 events, 92% done.
# Processed 7145000 events, 92% done.
# Processed 7150000 events, 92% done.
# Processed 7155000 events, 92% done.
# Processed 7160000 events, 92% done.
# Processed 7165000 events, 92% done.
# Processed 7170000 events, 92% done.
# Processed 7175000 events, 92% done.
# Processed 7180000 events, 92% done.
# Processed 7185000 events, 92% done.
# Processed 7190000 events, 92% done.
# Processed 7195000 events, 92% done.
# Processed 7200000 events, 92% done.
# Processed 7205000 events, 92% done.
# Processed 7210000 events, 92% done.
# Processed 7215000 events, 93% done.
# Processed 7220000 events, 93% done.
# Processed 7225000 events, 93% done.
# Processed 7230000 events, 93% done.
# Processed 7235000 events, 93% done.
# Processed 7240000 events, 93% done.
# Processed 7245000 events, 93% done.
# Processed 7250000 events, 93% done.
# Processed 7255000 events, 93% done.
# Processed 7260000 events, 93% done.
# Processed 7265000 events, 93% done.
# Processed 7270000 events, 93% done.
# Processed 7275000 events, 93% done.
# Processed 7280000 events, 93% done.
# Processed 7285000 events, 93% done.
# Processed 7290000 events, 93% done.
# Processed 7295000 events, 94% done.
# Processed 7300000 events, 94% done.
# Processed 7305000 events, 94% done.
# Processed 7310000 events, 94% done.
# Processed 7315000 events, 94% done.
# Processed 7320000 events, 94% done.
# Processed 7325000 events, 94% done.
# Processed 7330000 events, 94% done.
# Processed 7335000 events, 94% done.
# Processed 7340000 events, 94% done.
# Processed 7345000 events, 94% done.
# Processed 7350000 events, 94% done.
# Processed 7355000 events, 94% done.
# Processed 7360000 events, 94% done.
# Processed 7365000 events, 94% done.
# Processed 7370000 events, 95% done.
# Processed 7375000 events, 95% done.
# Processed 7380000 events, 95% done.
# Processed 7385000 events, 95% done.
# Processed 7390000 events, 95% done.
# Processed 7395000 events, 95% done.
# Processed 7400000 events, 95% done.
# Processed 7405000 events, 95% done.
# Processed 7410000 events, 95% done.
# Processed 7415000 events, 95% done.
# Processed 7420000 events, 95% done.
# Processed 7425000 events, 95% done.
# Processed 7430000 events, 95% done.
# Processed 7435000 events, 95% done.
# Processed 7440000 events, 95% done.
# Processed 7445000 events, 95% done.
# Processed 7450000 events, 96% done.
# Processed 7455000 events, 96% done.
# Processed 7460000 events, 96% done.
# Processed 7465000 events, 96% done.
# Processed 7470000 events, 96% done.
# Processed 7475000 events, 96% done.
# Processed 7480000 events, 96% done.
# Processed 7485000 events, 96% done.
# Processed 7490000 events, 96% done.
# Processed 7495000 events, 96% done.
# Processed 7500000 events, 96% done.
# Processed 7505000 events, 96% done.
# Processed 7510000 events, 96% done.
# Processed 7515000 events, 96% done.
# Processed 7520000 events, 96% done.
# Processed 7525000 events, 96% done.
# Processed 7530000 events, 97% done.
# Processed 7535000 events, 97% done.
# Processed 7540000 events, 97% done.
# Processed 7545000 events, 97% done.
# Processed 7550000 events, 97% done.
# Processed 7555000 events, 97% done.
# Processed 7560000 events, 97% done.
# Processed 7565000 events, 97% done.
# Processed 7570000 events, 97% done.
# Processed 7575000 events, 97% done.
# Processed 7580000 events, 97% done.
# Processed 7585000 events, 97% done.
# Processed 7590000 events, 97% done.
# Processed 7595000 events, 97% done.
# Processed 7600000 events, 97% done.
# Processed 7605000 events, 98% done.
# Processed 7610000 events, 98% done.
# Processed 7615000 events, 98% done.
# Processed 7620000 events, 98% done.
# Processed 7625000 events, 98% done.
# Processed 7630000 events, 98% done.
# Processed 7635000 events, 98% done.
# Processed 7640000 events, 98% done.
# Processed 7645000 events, 98% done.
# Processed 7650000 events, 98% done.
# Processed 7655000 events, 98% done.
# Processed 7660000 events, 98% done.
# Processed 7665000 events, 98% done.
# Processed 7670000 events, 98% done.
# Processed 7675000 events, 98% done.
# Processed 7680000 events, 98% done.
# Processed 7685000 events, 99% done.
# Processed 7690000 events, 99% done.
# Processed 7695000 events, 99% done.
# Processed 7700000 events, 99% done.
# Processed 7705000 events, 99% done.
# Processed 7710000 events, 99% done.
# Processed 7715000 events, 99% done.
# Processed 7720000 events, 99% done.
# Processed 7725000 events, 99% done.
# Processed 7730000 events, 99% done.
# Processed 7735000 events, 99% done.
# Processed 7740000 events, 99% done.
# Processed 7745000 events, 99% done.
# Processed 7750000 events, 99% done.
# Processed 7755000 events, 99% done.
# Processed 7760000 events, 100% done.
# Processed 7765000 events, 100% done.
# Processed 7770000 events, 100% done.
# Processed 7775000 events, 100% done.
# Processed 7780000 events, 100% done.
# Processed 7785000 events, 100% done.
# Processed 7790000 events, 100% done.
# Processed 7795000 events, 100% done.

# %%
# EventLoop analysis over the signal MC ntuples gluon gluon fusion -> H -> gamma gamma

# write the file we will output our Higgs signal MC histograms into
out_hists_ggfHiggs = TFile.Open(output_path+"ggfHiggs.root", "RECREATE")

# read in our signal MC ntuples gluon gluon fusion -> H -> gamma gamma
tree_ggfMC = TChain("mini")
tree_ggfMC.Add(ntuple_path+"/MC/mc_343981.ggH125_gamgam.GamGam.root")

# loop over the data ntuple to process needed info into histograms
eventLooper(tree_ggfMC, out_hists_ggfHiggs, False)
# Out:
# there are 1054711 event in the TTree
# Registering histogram...  photon_pT_1
# Registering histogram...  photon_pT_2
# Registering histogram...  photon_E_1
# Registering histogram...  photon_E_2
# Registering histogram...  photon_eta_1
# Registering histogram...  photon_eta_2
# Registering histogram...  photon_phi_1
# Registering histogram...  photon_phi_2
# Registering histogram...  diphoton_mass
# Processed 5000 events, 0% done.
# Processed 10000 events, 1% done.
# Processed 15000 events, 1% done.
# Processed 20000 events, 2% done.
# Processed 25000 events, 2% done.
# Processed 30000 events, 3% done.
# Processed 35000 events, 3% done.
# Processed 40000 events, 4% done.
# Processed 45000 events, 4% done.
# Processed 50000 events, 5% done.
# Processed 55000 events, 5% done.
# Processed 60000 events, 6% done.
# Processed 65000 events, 6% done.
# Processed 70000 events, 7% done.
# Processed 75000 events, 7% done.
# Processed 80000 events, 8% done.
# Processed 85000 events, 8% done.
# Processed 90000 events, 9% done.
# Processed 95000 events, 9% done.
# Processed 100000 events, 9% done.
# Processed 105000 events, 10% done.
# Processed 110000 events, 10% done.
# Processed 115000 events, 11% done.
# Processed 120000 events, 11% done.
# Processed 125000 events, 12% done.
# Processed 130000 events, 12% done.
# Processed 135000 events, 13% done.
# Processed 140000 events, 13% done.
# Processed 145000 events, 14% done.
# Processed 150000 events, 14% done.
# Processed 155000 events, 15% done.
# Processed 160000 events, 15% done.
# Processed 165000 events, 16% done.
# Processed 170000 events, 16% done.
# Processed 175000 events, 17% done.
# Processed 180000 events, 17% done.
# Processed 185000 events, 18% done.
# Processed 190000 events, 18% done.
# Processed 195000 events, 18% done.
# Processed 200000 events, 19% done.
# Processed 205000 events, 19% done.
# Processed 210000 events, 20% done.
# Processed 215000 events, 20% done.
# Processed 220000 events, 21% done.
# Processed 225000 events, 21% done.
# Processed 230000 events, 22% done.
# Processed 235000 events, 22% done.
# Processed 240000 events, 23% done.
# Processed 245000 events, 23% done.
# Processed 250000 events, 24% done.
# Processed 255000 events, 24% done.
# Processed 260000 events, 25% done.
# Processed 265000 events, 25% done.
# Processed 270000 events, 26% done.
# Processed 275000 events, 26% done.
# Processed 280000 events, 27% done.
# Processed 285000 events, 27% done.
# Processed 290000 events, 27% done.
# Processed 295000 events, 28% done.
# Processed 300000 events, 28% done.
# Processed 305000 events, 29% done.
# Processed 310000 events, 29% done.
# Processed 315000 events, 30% done.
# Processed 320000 events, 30% done.
# Processed 325000 events, 31% done.
# Processed 330000 events, 31% done.
# Processed 335000 events, 32% done.
# Processed 340000 events, 32% done.
# Processed 345000 events, 33% done.
# Processed 350000 events, 33% done.
# Processed 355000 events, 34% done.
# Processed 360000 events, 34% done.
# Processed 365000 events, 35% done.
# Processed 370000 events, 35% done.
# Processed 375000 events, 36% done.
# Processed 380000 events, 36% done.
# Processed 385000 events, 37% done.
# Processed 390000 events, 37% done.
# Processed 395000 events, 37% done.
# Processed 400000 events, 38% done.
# Processed 405000 events, 38% done.
# Processed 410000 events, 39% done.
# Processed 415000 events, 39% done.
# Processed 420000 events, 40% done.
# Processed 425000 events, 40% done.
# Processed 430000 events, 41% done.
# Processed 435000 events, 41% done.
# Processed 440000 events, 42% done.
# Processed 445000 events, 42% done.
# Processed 450000 events, 43% done.
# Processed 455000 events, 43% done.
# Processed 460000 events, 44% done.
# Processed 465000 events, 44% done.
# Processed 470000 events, 45% done.
# Processed 475000 events, 45% done.
# Processed 480000 events, 46% done.
# Processed 485000 events, 46% done.
# Processed 490000 events, 46% done.
# Processed 495000 events, 47% done.
# Processed 500000 events, 47% done.
# Processed 505000 events, 48% done.
# Processed 510000 events, 48% done.
# Processed 515000 events, 49% done.
# Processed 520000 events, 49% done.
# Processed 525000 events, 50% done.
# Processed 530000 events, 50% done.
# Processed 535000 events, 51% done.
# Processed 540000 events, 51% done.
# Processed 545000 events, 52% done.
# Processed 550000 events, 52% done.
# Processed 555000 events, 53% done.
# Processed 560000 events, 53% done.
# Processed 565000 events, 54% done.
# Processed 570000 events, 54% done.
# Processed 575000 events, 55% done.
# Processed 580000 events, 55% done.
# Processed 585000 events, 55% done.
# Processed 590000 events, 56% done.
# Processed 595000 events, 56% done.
# Processed 600000 events, 57% done.
# Processed 605000 events, 57% done.
# Processed 610000 events, 58% done.
# Processed 615000 events, 58% done.
# Processed 620000 events, 59% done.
# Processed 625000 events, 59% done.
# Processed 630000 events, 60% done.
# Processed 635000 events, 60% done.
# Processed 640000 events, 61% done.
# Processed 645000 events, 61% done.
# Processed 650000 events, 62% done.
# Processed 655000 events, 62% done.
# Processed 660000 events, 63% done.
# Processed 665000 events, 63% done.
# Processed 670000 events, 64% done.
# Processed 675000 events, 64% done.
# Processed 680000 events, 64% done.
# Processed 685000 events, 65% done.
# Processed 690000 events, 65% done.
# Processed 695000 events, 66% done.
# Processed 700000 events, 66% done.
# Processed 705000 events, 67% done.
# Processed 710000 events, 67% done.
# Processed 715000 events, 68% done.
# Processed 720000 events, 68% done.
# Processed 725000 events, 69% done.
# Processed 730000 events, 69% done.
# Processed 735000 events, 70% done.
# Processed 740000 events, 70% done.
# Processed 745000 events, 71% done.
# Processed 750000 events, 71% done.
# Processed 755000 events, 72% done.
# Processed 760000 events, 72% done.
# Processed 765000 events, 73% done.
# Processed 770000 events, 73% done.
# Processed 775000 events, 73% done.
# Processed 780000 events, 74% done.
# Processed 785000 events, 74% done.
# Processed 790000 events, 75% done.
# Processed 795000 events, 75% done.
# Processed 800000 events, 76% done.
# Processed 805000 events, 76% done.
# Processed 810000 events, 77% done.
# Processed 815000 events, 77% done.
# Processed 820000 events, 78% done.
# Processed 825000 events, 78% done.
# Processed 830000 events, 79% done.
# Processed 835000 events, 79% done.
# Processed 840000 events, 80% done.
# Processed 845000 events, 80% done.
# Processed 850000 events, 81% done.
# Processed 855000 events, 81% done.
# Processed 860000 events, 82% done.
# Processed 865000 events, 82% done.
# Processed 870000 events, 82% done.
# Processed 875000 events, 83% done.
# Processed 880000 events, 83% done.
# Processed 885000 events, 84% done.
# Processed 890000 events, 84% done.
# Processed 895000 events, 85% done.
# Processed 900000 events, 85% done.
# Processed 905000 events, 86% done.
# Processed 910000 events, 86% done.
# Processed 915000 events, 87% done.
# Processed 920000 events, 87% done.
# Processed 925000 events, 88% done.
# Processed 930000 events, 88% done.
# Processed 935000 events, 89% done.
# Processed 940000 events, 89% done.
# Processed 945000 events, 90% done.
# Processed 950000 events, 90% done.
# Processed 955000 events, 91% done.
# Processed 960000 events, 91% done.
# Processed 965000 events, 91% done.
# Processed 970000 events, 92% done.
# Processed 975000 events, 92% done.
# Processed 980000 events, 93% done.
# Processed 985000 events, 93% done.
# Processed 990000 events, 94% done.
# Processed 995000 events, 94% done.
# Processed 1000000 events, 95% done.
# Processed 1005000 events, 95% done.
# Processed 1010000 events, 96% done.
# Processed 1015000 events, 96% done.
# Processed 1020000 events, 97% done.
# Processed 1025000 events, 97% done.
# Processed 1030000 events, 98% done.
# Processed 1035000 events, 98% done.
# Processed 1040000 events, 99% done.
# Processed 1045000 events, 99% done.
# Processed 1050000 events, 100% done.

# %%
# EventLoop analysis over the signal MC ntuples Vector-boson fusion -> H -> gamma gamma

# write the file we will output our Higgs signal MC histograms into
out_hists_vbfHiggs = TFile.Open(output_path+"VBFHiggs.root", "RECREATE")

# read in our signal MC ntuples gluon gluon fusion -> H -> gamma gamma
tree_vbfMC = TChain("mini")
tree_vbfMC.Add(ntuple_path+"/MC/mc_345041.VBFH125_gamgam.GamGam.root")

# loop over the data ntuple to process needed info into histograms
eventLooper(tree_vbfMC, out_hists_vbfHiggs, False)
# Out:
# there are 497468 event in the TTree
# Registering histogram...  photon_pT_1
# Registering histogram...  photon_pT_2
# Registering histogram...  photon_E_1
# Registering histogram...  photon_E_2
# Registering histogram...  photon_eta_1
# Registering histogram...  photon_eta_2
# Registering histogram...  photon_phi_1
# Registering histogram...  photon_phi_2
# Registering histogram...  diphoton_mass
# Processed 5000 events, 1% done.
# Processed 10000 events, 2% done.
# Processed 15000 events, 3% done.
# Processed 20000 events, 4% done.
# Processed 25000 events, 5% done.
# Processed 30000 events, 6% done.
# Processed 35000 events, 7% done.
# Processed 40000 events, 8% done.
# Processed 45000 events, 9% done.
# Processed 50000 events, 10% done.
# Processed 55000 events, 11% done.
# Processed 60000 events, 12% done.
# Processed 65000 events, 13% done.
# Processed 70000 events, 14% done.
# Processed 75000 events, 15% done.
# Processed 80000 events, 16% done.
# Processed 85000 events, 17% done.
# Processed 90000 events, 18% done.
# Processed 95000 events, 19% done.
# Processed 100000 events, 20% done.
# Processed 105000 events, 21% done.
# Processed 110000 events, 22% done.
# Processed 115000 events, 23% done.
# Processed 120000 events, 24% done.
# Processed 125000 events, 25% done.
# Processed 130000 events, 26% done.
# Processed 135000 events, 27% done.
# Processed 140000 events, 28% done.
# Processed 145000 events, 29% done.
# Processed 150000 events, 30% done.
# Processed 155000 events, 31% done.
# Processed 160000 events, 32% done.
# Processed 165000 events, 33% done.
# Processed 170000 events, 34% done.
# Processed 175000 events, 35% done.
# Processed 180000 events, 36% done.
# Processed 185000 events, 37% done.
# Processed 190000 events, 38% done.
# Processed 195000 events, 39% done.
# Processed 200000 events, 40% done.
# Processed 205000 events, 41% done.
# Processed 210000 events, 42% done.
# Processed 215000 events, 43% done.
# Processed 220000 events, 44% done.
# Processed 225000 events, 45% done.
# Processed 230000 events, 46% done.
# Processed 235000 events, 47% done.
# Processed 240000 events, 48% done.
# Processed 245000 events, 49% done.
# Processed 250000 events, 50% done.
# Processed 255000 events, 51% done.
# Processed 260000 events, 52% done.
# Processed 265000 events, 53% done.
# Processed 270000 events, 54% done.
# Processed 275000 events, 55% done.
# Processed 280000 events, 56% done.
# Processed 285000 events, 57% done.
# Processed 290000 events, 58% done.
# Processed 295000 events, 59% done.
# Processed 300000 events, 60% done.
# Processed 305000 events, 61% done.
# Processed 310000 events, 62% done.
# Processed 315000 events, 63% done.
# Processed 320000 events, 64% done.
# Processed 325000 events, 65% done.
# Processed 330000 events, 66% done.
# Processed 335000 events, 67% done.
# Processed 340000 events, 68% done.
# Processed 345000 events, 69% done.
# Processed 350000 events, 70% done.
# Processed 355000 events, 71% done.
# Processed 360000 events, 72% done.
# Processed 365000 events, 73% done.
# Processed 370000 events, 74% done.
# Processed 375000 events, 75% done.
# Processed 380000 events, 76% done.
# Processed 385000 events, 77% done.
# Processed 390000 events, 78% done.
# Processed 395000 events, 79% done.
# Processed 400000 events, 80% done.
# Processed 405000 events, 81% done.
# Processed 410000 events, 82% done.
# Processed 415000 events, 83% done.
# Processed 420000 events, 84% done.
# Processed 425000 events, 85% done.
# Processed 430000 events, 86% done.
# Processed 435000 events, 87% done.
# Processed 440000 events, 88% done.
# Processed 445000 events, 89% done.
# Processed 450000 events, 90% done.
# Processed 455000 events, 91% done.
# Processed 460000 events, 92% done.
# Processed 465000 events, 93% done.
# Processed 470000 events, 94% done.
# Processed 475000 events, 95% done.
# Processed 480000 events, 96% done.
# Processed 485000 events, 97% done.
# Processed 490000 events, 98% done.
# Processed 495000 events, 100% done.

# %%
# Now maybe we want to also have combined Signal MC Histograms containing both ggf and vbf production? can combine root files via hadd command:
# and we can run a bash command via python as so....
command = "hadd -f histograms/GamGam_root/allHiggs.root histograms/GamGam_root/ggfHiggs.root histograms/GamGam_root/VBFHiggs.root"
print(command)
os.system(command)
# Out:
# hadd -f histograms/GamGam_root/allHiggs.root histograms/GamGam_root/ggfHiggs.root histograms/GamGam_root/VBFHiggs.root
# 0
# hadd Target file: histograms/GamGam_root/allHiggs.root
# hadd compression setting for all output: 101
# hadd Source file 1: histograms/GamGam_root/ggfHiggs.root
# hadd Source file 2: histograms/GamGam_root/VBFHiggs.root
# hadd Target path: histograms/GamGam_root/allHiggs.root:/
